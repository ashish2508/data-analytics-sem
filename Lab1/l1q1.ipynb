# %%
p,c,m=80,90,91

# %%
age=20
male=True
point=0.5
name="ashish"
z = 3 + 4j

# %%
type(age)
# Out:
# int

# %%
type(male)
# Out:
# bool

# %%
type(point)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
type(z)
# Out:
# complex

# %%
Age=str(age)

# %%
type(Age)
# Out:
# str

# %%
Name=float(name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 Name=float(name)
#
# ValueError: could not convert string to float: 'ashish'

# %%
a,b=10,5
a+b
# Out:
# 15

# %%
a^b
# Out:
# 15

# %%
a**b
# Out:
# 100000

# %%
c=11
# !c
# Out:
# 'c' is not recognized as an internal or external command,
# operable program or batch file.

# %%
~c
# Out:
# -12

# %%
7&2
# Out:
# 2

# %%
7>2 and 1<2
# Out:
# True
