# %%
a,b=5,10

# %%
print(a+b)
# Out:
# 15

# %%
import math
pi = math.pi
r=64
area=pi*r*r
print(area)
# Out:
# 12867.963509103793

# %%
paise=18972
rupees=int(paise/100)
paises=rupees%100
print("rupees:",rupees,"paises:",paises)
# Out:
# rupees: 189 paises: 89

# %%
metres = 13664329
km=metres/1000
print(km)
# Out:
# 13664.329

# %%
a, b = 11, 19
print(a if a > b else b)
# Out:
# 19
