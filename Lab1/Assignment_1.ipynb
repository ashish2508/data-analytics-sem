# %%
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
add=a+b
print("The sum of",a,"and",b,"is",add)
# Out:
# The sum of 5 and 6 is 11

# %%
pi = 3.14
r=16
area=pi*r*r
print(area)
# Out:
# 803.84

# %%
paise=18972
rupees=int(paise/100)
paises=paise%100
print("rupees:",rupees,"paises:",paises)
# Out:
# rupees: 189 paises: 72

# %%
metres = 13664329
km=int(metres/1000)
mtr=metres%1000

print("kilometres:",km,"metres:",mtr)
# Out:
# kilometres: 13664 metres: 329

# %%
a, b = 99, 19
print("a:",a if a > b else ("b:", b))
# Out:
# a: 99
