# %%
import random

nums = [random.randint(2, 100) for i in range(10)]
for n in nums:
    f = all(n % i for i in range(2, int(n**0.5) + 1))
    print(n," is ", "Prime" if f else "Compoiste")
# Out:
# 43  is  Prime
# 41  is  Prime
# 79  is  Prime
# 74  is  Compoiste
# 4  is  Compoiste
# 38  is  Compoiste
# 84  is  Compoiste
# 94  is  Compoiste
# 13  is  Prime
# 66  is  Compoiste
