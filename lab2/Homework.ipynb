# %%
import statistics as st
import numpy as np


data=[600,470,170,430,300]
mean_value=st.mean(data)
print('Mean value:',mean_value)

median_value=st.median(data)
print('Median value',median_value)

variance_value=st.variance(data)
print('Variance:',variance_value)

sd=st.pstdev(data)
print('Standard Devitiation:',sd)

maximum=max(data)
minimum=min(data)
range=maximum-minimum 
print('Range:',range)

q1 = np.quantile(data, 0.25) 
q2 = np.quantile(data, 0.50) 
q3 = np.quantile(data, 0.75) 

print("Q1:", q1)
print("Q2 (Median):", q2)
print("Q3:", q3)
# Out:
# Mean value: 394
# Median value 430
# Variance: 27130
# Standard Devitiation: 147.32277488562318
# Range: 430
# Q1: 300.0
# Q2 (Median): 430.0
# Q3: 470.0

# %%
import statistics as st
import numpy as np
import matplotlib.pyplot as plt

data=[15,29,8,42,35,21,18,42,26]
mean_value=st.mean(data)
print('Mean value:',mean_value)

median_value=st.median(data)
print('Median value',median_value)

variance_value=st.variance(data)
print('Variance:',variance_value)

sd=st.pstdev(data)
print('Standard Devitiation:',sd)

maximum=max(data)
minimum=min(data)
range=maximum-minimum 
print('Range:',range)

q1 = np.quantile(data, 0.25) 
q2 = np.quantile(data, 0.50)
q3 = np.quantile(data, 0.75)

print("Q1:", q1)
print("Q2 (Median):", q2)
print("Q3:", q3)



plt.hist(data, bins=5, edgecolor='black')


plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(median_value, color='green', linestyle='dashed', linewidth=2, label='Median')

plt.title("Histogram of Data")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.legend()

plt.show()
# Out:
# Mean value: 26.22222222222222
# Median value 26
# Variance: 141.94444444444446
# Standard Devitiation: 11.232668405422322
# Range: 34
# Q1: 18.0
# Q2 (Median): 26.0
# Q3: 35.0

# %%
import numpy as np
data=[12,12,12,12,12,12,12,12,12,12,12,12]
q1 = np.quantile(data, 0.25
q2 = np.quantile(data, 0.50) 
q3 = np.quantile(data, 0.75)

print("Q1:", q1)
print("Q2 (Median):", q2)
print("Q3:", q3)
print("IQR:",q3-q1)
# Out:
# Q1: 12.0
# Q2 (Median): 12.0
# Q3: 12.0
# IQR: 0.0

# %%
import matplotlib.pyplot as plt

sizes = [2,4,6,8,10,12,14]
freq = [5,12,27,10,8,3,1]

plt.hist(
    sizes,
    bins=range(2,18,2),  
    weights=freq,        
    edgecolor="black",
    align="left"
)

plt.xlabel("Size of Items")
plt.ylabel("Frequency")
plt.title("Histogram for Size Range 2–18")

plt.show()

# %%
import matplotlib.pyplot as plt

sizes = [10,15,20,25,30,35,40]
freq = [2,5,12,18,30,21,6]

bins = list(range(10, 45, 5)) 

plt.hist(
    sizes,
    bins=bins,
    weights=freq,
    edgecolor='black',
    align='left'
)

plt.xlabel("Size of Items")
plt.ylabel("Frequency")
plt.title("Histogram for Size Range 10–40")

plt.show()
